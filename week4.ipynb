# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Applications/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |           py37_0         148 KB  conda-forge
#     conda-4.8.0                |           py37_1         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.11.27~ --> conda-forge::ca-certificates-2019.11.28-hecc5488_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#   conda                                           pkgs/main --> conda-forge
#   openssl              pkgs/main::openssl-1.1.1d-h1de35cc_3 --> conda-forge::openssl-1.1.1d-h0b31af3_0
#
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 148 KB    | ##################################### | 100%
# conda-4.8.0          | 3.0 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'WZ30F0XKP15ZKWXK4ITIHSLWZMOMY0CVJIRUGHMUZSXEKL4K' # your Foursquare ID
CLIENT_SECRET = 'ZPT3FXFXV4HC2ITQU4Q3L2F5CLLD0SVMSKW1SMKHPPCLNIGJ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WZ30F0XKP15ZKWXK4ITIHSLWZMOMY0CVJIRUGHMUZSXEKL4K
# CLIENT_SECRET:ZPT3FXFXV4HC2ITQU4Q3L2F5CLLD0SVMSKW1SMKHPPCLNIGJ

# %%
address = 'Los Angeles, CA 90007'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 34.0536909 -118.2427666

# %%
search_query = 'market'
radius = 500
print(search_query + ' .... OK!')
# Out:
# market .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=WZ30F0XKP15ZKWXK4ITIHSLWZMOMY0CVJIRUGHMUZSXEKL4K&client_secret=ZPT3FXFXV4HC2ITQU4Q3L2F5CLLD0SVMSKW1SMKHPPCLNIGJ&ll=34.0536909,-118.2427666&v=20180604&query=market&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e01b39b153fd4001b28274d'},
#  'response': {'venues': [{'id': '4a8e02c9f964a520bb1120e3',
#     'name': 'Marukai Market',
#     'location': {'address': '123 Astronaut E S Onizuka St',
#      'crossStreet': 'E 1st St',
#      'lat': 34.050049249587744,
#      'lng': -118.24214765760863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.050049249587744,
#        'lng': -118.24214765760863}],
#      'distance': 409,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['123 Astronaut E S Onizuka St (E 1st St)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False},
#    {'id': '4aa01788f964a5203f3e20e3',
#     'name': 'City Hall Farmers Market',
#     'location': {'address': '1st St & Main St',
#      'crossStreet': 'Behind LA City Hall, next to City Hall East',
#      'lat': 34.05270581346987,
#      'lng': -118.24244334419971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05270581346987,
#        'lng': -118.24244334419971}],
#      'distance': 113,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1st St & Main St (Behind LA City Hall, next to City Hall East)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa941735',
#       'name': 'Farmers Market',
#       'pluralName': 'Farmers Markets',
#       'shortName': "Farmer's Market",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False},
#    {'id': '51364ea7e4b01b8cdaab23c8',
#     'name': 'Grand Park Downtown Farmers Market',
#     'location': {'address': 'First Street (Civic Center)',
#      'crossStreet': 'btw Spring & Broadway',
#      'lat': 34.05237399280374,
#      'lng': -118.24471617974383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05237399280374,
#        'lng': -118.24471617974383}],
#      'distance': 231,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['First Street (Civic Center) (btw Spring & Broadway)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa941735',
#       'name': 'Farmers Market',
#       'pluralName': 'Farmers Markets',
#       'shortName': "Farmer's Market",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False},
#    {'id': '4c31476b213c2d7f93cc335d',
#     'name': 'City of Los Angeles',
#     'location': {'lat': 34.05571721333726,
#      'lng': -118.24512004852294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05571721333726,
#        'lng': -118.24512004852294}],
#      'distance': 313,
#      'postalCode': '90013',
#      'cc': 'US',
#      'state': 'California',
#      'country': 'United States',
#      'formattedAddress': ['CA 90013', 'United States']},
#     'categories': [{'id': '50aa9e094b90af0d42d5de0d',
#       'name': 'City',
#       'pluralName': 'Cities',
#       'shortName': 'City',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False},
#    {'id': '512d1ac2e4b07446f5471c48',
#     'name': "Grand Park Farmer's Market",
#     'location': {'address': '210 W Temple St',
#      'lat': 34.05403479413261,
#      'lng': -118.2441336105644,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05403479413261,
#        'lng': -118.2441336105644}],
#      'distance': 131,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['210 W Temple St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False},
#    {'id': '4ee3a3bfd3e34ebcef130f44',
#     'name': 'Renegade Craft Fair',
#     'location': {'address': '1245 N Spring St',
#      'lat': 34.05444455981002,
#      'lng': -118.24447062358685,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05444455981002,
#        'lng': -118.24447062358685}],
#      'distance': 178,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1245 N Spring St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False},
#    {'id': '5a6c568567e5f249751fe4df',
#     'name': 'Tack Media - Digital Marketing Company Los Angeles',
#     'location': {'address': '5250 Lankershim Blvd',
#      'lat': 34.05306654063183,
#      'lng': -118.24418663978577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05306654063183,
#        'lng': -118.24418663978577}],
#      'distance': 148,
#      'postalCode': '91601',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['5250 Lankershim Blvd',
#       'Los Angeles, CA 91601',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3d',
#       'name': 'Advertising Agency',
#       'pluralName': 'Advertising Agencies',
#       'shortName': 'Advertising Agency',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False},
#    {'id': '58a6f942d4ab737624658de4',
#     'name': 'Elite Marketing Group, LLC',
#     'location': {'address': '9701 Wilshire Blvd',
#      'crossStreet': '10th Floor',
#      'lat': 34.053848773224665,
#      'lng': -118.24618220329285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.053848773224665,
#        'lng': -118.24618220329285}],
#      'distance': 315,
#      'postalCode': '90212',
#      'cc': 'US',
#      'city': 'Beverly Hills',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['9701 Wilshire Blvd (10th Floor)',
#       'Beverly Hills, CA 90212',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3d',
#       'name': 'Advertising Agency',
#       'pluralName': 'Advertising Agencies',
#       'shortName': 'Advertising Agency',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577169917',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fa941735', 'name': 'F...    False
# 2  [{'id': '4bf58dd8d48988d1fa941735', 'name': 'F...    False
# 3  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
#
#                          id              location.address location.cc  \
# 0  4a8e02c9f964a520bb1120e3  123 Astronaut E S Onizuka St          US
# 1  4aa01788f964a5203f3e20e3              1st St & Main St          US
# 2  51364ea7e4b01b8cdaab23c8   First Street (Civic Center)          US
# 3  4c31476b213c2d7f93cc335d                           NaN          US
# 4  512d1ac2e4b07446f5471c48               210 W Temple St          US
#
#   location.city location.country                         location.crossStreet  \
# 0   Los Angeles    United States                                     E 1st St
# 1   Los Angeles    United States  Behind LA City Hall, next to City Hall East
# 2   Los Angeles    United States                        btw Spring & Broadway
# 3           NaN    United States                                          NaN
# 4   Los Angeles    United States                                          NaN
#
#    location.distance                          location.formattedAddress  \
# 0                409  [123 Astronaut E S Onizuka St (E 1st St), Los ...
# 1                113  [1st St & Main St (Behind LA City Hall, next t...
# 2                231  [First Street (Civic Center) (btw Spring & Bro...
# 3                313                          [CA 90013, United States]
# 4                131  [210 W Temple St, Los Angeles, CA 90012, Unite...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 34.05004924958774...     34.050049
# 1  [{'label': 'display', 'lat': 34.05270581346987...     34.052706
# 2  [{'label': 'display', 'lat': 34.05237399280374...     34.052374
# 3  [{'label': 'display', 'lat': 34.05571721333726...     34.055717
# 4  [{'label': 'display', 'lat': 34.05403479413261...     34.054035
#
#    location.lng location.postalCode location.state  \
# 0   -118.242148               90012             CA
# 1   -118.242443               90012             CA
# 2   -118.244716               90012             CA
# 3   -118.245120               90013     California
# 4   -118.244134               90012             CA
#
#                                  name    referralId
# 0                      Marukai Market  v-1577169917
# 1            City Hall Farmers Market  v-1577169917
# 2  Grand Park Downtown Farmers Market  v-1577169917
# 3                 City of Los Angeles  v-1577169917
# 4          Grand Park Farmer's Market  v-1577169917

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                 name           categories  \
# 0                                     Marukai Market          Supermarket
# 1                           City Hall Farmers Market       Farmers Market
# 2                 Grand Park Downtown Farmers Market       Farmers Market
# 3                                City of Los Angeles                 City
# 4                         Grand Park Farmer's Market                 Park
# 5                                Renegade Craft Fair  Arts & Crafts Store
# 6  Tack Media - Digital Marketing Company Los Ang...   Advertising Agency
# 7                         Elite Marketing Group, LLC   Advertising Agency
#
#                         address  cc           city        country  \
# 0  123 Astronaut E S Onizuka St  US    Los Angeles  United States
# 1              1st St & Main St  US    Los Angeles  United States
# 2   First Street (Civic Center)  US    Los Angeles  United States
# 3                           NaN  US            NaN  United States
# 4               210 W Temple St  US    Los Angeles  United States
# 5              1245 N Spring St  US    Los Angeles  United States
# 6          5250 Lankershim Blvd  US    Los Angeles  United States
# 7            9701 Wilshire Blvd  US  Beverly Hills  United States
#
#                                    crossStreet  distance  \
# 0                                     E 1st St       409
# 1  Behind LA City Hall, next to City Hall East       113
# 2                        btw Spring & Broadway       231
# 3                                          NaN       313
# 4                                          NaN       131
# 5                                          NaN       178
# 6                                          NaN       148
# 7                                   10th Floor       315
#
#                                     formattedAddress  \
# 0  [123 Astronaut E S Onizuka St (E 1st St), Los ...
# 1  [1st St & Main St (Behind LA City Hall, next t...
# 2  [First Street (Civic Center) (btw Spring & Bro...
# 3                          [CA 90013, United States]
# 4  [210 W Temple St, Los Angeles, CA 90012, Unite...
# 5  [1245 N Spring St, Los Angeles, CA 90012, Unit...
# 6  [5250 Lankershim Blvd, Los Angeles, CA 91601, ...
# 7  [9701 Wilshire Blvd (10th Floor), Beverly Hill...
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 34.05004924958774...  34.050049 -118.242148
# 1  [{'label': 'display', 'lat': 34.05270581346987...  34.052706 -118.242443
# 2  [{'label': 'display', 'lat': 34.05237399280374...  34.052374 -118.244716
# 3  [{'label': 'display', 'lat': 34.05571721333726...  34.055717 -118.245120
# 4  [{'label': 'display', 'lat': 34.05403479413261...  34.054035 -118.244134
# 5  [{'label': 'display', 'lat': 34.05444455981002...  34.054445 -118.244471
# 6  [{'label': 'display', 'lat': 34.05306654063183...  34.053067 -118.244187
# 7  [{'label': 'display', 'lat': 34.05384877322466...  34.053849 -118.246182
#
#   postalCode       state                        id
# 0      90012          CA  4a8e02c9f964a520bb1120e3
# 1      90012          CA  4aa01788f964a5203f3e20e3
# 2      90012          CA  51364ea7e4b01b8cdaab23c8
# 3      90013  California  4c31476b213c2d7f93cc335d
# 4      90012          CA  512d1ac2e4b07446f5471c48
# 5      90012          CA  4ee3a3bfd3e34ebcef130f44
# 6      91601          CA  5a6c568567e5f249751fe4df
# 7      90212          CA  58a6f942d4ab737624658de4

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='USC',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
